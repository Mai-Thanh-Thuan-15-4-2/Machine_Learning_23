# %% [markdown]
# <a href="https://colab.research.google.com/github/Mai-Thanh-Thuan-15-4-2/Machine_Learning_23/blob/main/Lab_3_20130127_MaiThanhThuan.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Deadline: 23:59, 04/03/2023**

# %% [markdown]
# # Task 1.
# The main aim of this task is to get familiar with the tasks of preprocessing data using Scikit-learn – a Python-based Machine Learning framework and Linear Regression.

# %% [markdown]
# For given 2 datasets (preprocessing_weather.csv, preprocessing_salary_dummy.csv),
# *   Identify issues with these datasets
# *   Then, apply preprocessing techniques to the datasets

# %% [markdown]
# #Task 1.1. Dataset preprocessing_weather.csv

# %% [markdown]
# **Issues**:
#
#
# 1.   List item
# 2.   List item
# 3.   List item
# 4.   List item
# ....

# %% [markdown]
# **Preprocessing dataset**:

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# %cd '/content/gdrive/MyDrive/20130127_MaiThanhThuan'
# Out:
# Mounted at /content/gdrive
# /content/gdrive/MyDrive/20130127_MaiThanhThuan

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
#import
import pandas as pd
import numpy as np
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import StandardScaler
from sklearn.impute import SimpleImputer
from sklearn.model_selection import train_test_split
from matplotlib import pyplot as pt
from sklearn.metrics import r2_score
sc = StandardScaler()
# read csv file
df = pd.read_csv('/content/drive/MyDrive/20130127_MaiThanhThuan/preprocessing_weather.csv')
df.head(10)
imputer = SimpleImputer(missing_values=np.nan, strategy= "mean")
x = df.iloc[:,3:5].values
imputer.fit_transform(x)
# Out:
# array([[85.        ,  0.        ],
#        [90.        ,  1.        ],
#        [86.        ,  0.        ],
#        [96.        ,  0.        ],
#        [80.        ,  0.        ],
#        [70.        ,  1.        ],
#        [65.        ,  1.        ],
#        [95.        ,  0.        ],
#        [82.53846154,  0.        ],
#        [80.        ,  0.        ],
#        [70.        ,  1.        ],
#        [90.        ,  1.        ],
#        [75.        ,  0.        ],
#        [91.        ,  1.        ]])

# %% [markdown]
# #Task 1.2. Dataset preprocessing_salary_dummy.csv

# %% [markdown]
# **Issues**:
#
#
# 1.   List item
# 2.   List item
# 3.   List item
# 4.   List item
# ....

# %% [markdown]
# **Preprocessing dataset**:

# %%
#code
df2 = pd.read_csv('/content/drive/MyDrive/20130127_MaiThanhThuan/preprocessing_salary_dummy.csv')
df2.head(10)
# Out:
#    No    Country   Age     Salary  Purchased
# 0   1     France  44.0     72000.0        No
# 1   2      Spain  27.0     48000.0       Yes
# 2   3    Germany  30.0     54000.0        No
# 3   4      Spain  38.0     61000.0        No
# 4   5    Germany  40.0         NaN       Yes
# 5   6     France  35.0     58000.0       Yes
# 6   7      Spain   NaN     52000.0        No
# 7   8     France  48.0     79000.0       Yes
# 8   9    Germany  50.0     83000.0        No
# 9  10     France  37.0     67000.0       Yes

# %%
imputer = SimpleImputer(missing_values=np.nan, strategy= "mean")
x = df2.iloc[:,2:4].values
imputer.fit_transform(x)
# Out:
# array([[4.40000000e+01, 7.20000000e+04],
#        [2.70000000e+01, 4.80000000e+04],
#        [3.00000000e+01, 5.40000000e+04],
#        [3.80000000e+01, 6.10000000e+04],
#        [4.00000000e+01, 6.37777778e+04],
#        [3.50000000e+01, 5.80000000e+04],
#        [3.87777778e+01, 5.20000000e+04],
#        [4.80000000e+01, 7.90000000e+04],
#        [5.00000000e+01, 8.30000000e+04],
#        [3.70000000e+01, 6.70000000e+04]])

# %% [markdown]
# # **Task 2**. Simple Linear Regression in Scikit-Learn
# ---
# # **Usage:**
# > **Step 1**: build a model
# ![image.png](data:image/png;base64,...)
#
# > **Step 2**: test the model
#
# *   With test set:
# `y_pred = regressor.predict(X_test)`
#
# *   With a single value ("predict" method always expects a 2D array as the format of its inputs)
# `regressor.predict([[12]])`
#
# > **Step 3**:
# *   get w0, w1 , w2, …,
# -- W0: `regressor.intercept_`
# -- w1, w2, …: `regressor.coef_`
# *   R^2 score: sum of squared r(i)
# `r(i) = y(i) - f(x(i))`: residual of ith instance
#
#
# > **Metrics**:
# *   metrics.explained_variance_score(y_test, y_pred)
# *   metrics.mean_absolute_error(y_ test, y_pred)
# *   metrics.mean_squared_error(y_ test, y_pred[, ...])
# *   metrics.mean_squared_log_error(y_ test, y_pred)
# *   metrics.median_absolute_error(y_ test, y_pred)
# *   metrics.r2_score(y_ test, y_pred[, ...])

# %% [markdown]
# ---

# %% [markdown]
# # Tasks
# The main aim of these tasks is to get familiar with Linear Regression problems. Apply LinearRegression to the following datasets. Note the error obtained and coefficients
# *   **dataset1.csv** - a synthetic dataset including 5 points (1-dimensional data) with one target
# *   **dataset2.csv** - a synthetic dataset including 1000 points (3-dimensional data) with one target variable. The variables are named x1, x2, x3, y. y is the variable to be regressed. Split the dataset into training set and test set (70% for training set and 30% for test set).

# %% [markdown]
# # Task 2.1. dataset1.csv

# %%
df3 = pd.read_csv('/content/drive/MyDrive/20130127_MaiThanhThuan/dataset1.csv')
X_train = df3[['x']]
y_train = df3[['y']]
X_train
# Out:
#    x
# 0  1
# 1  2
# 2  4
# 3  3
# 4  5

# %%
regressor = LinearRegression()
regressor.fit(X_train, y_train)
print(regressor.intercept_)
print(regressor.coef_)
# Out:
# [0.4]
# [[0.8]]

# %%
y_pred = regressor.predict(X_train)
y_pred
# Out:
# array([[1.2],
#        [2. ],
#        [3.6],
#        [2.8],
#        [4.4]])

# %%
from sklearn import metrics
r2 = metrics.r2_score(X_train, y_pred)
r2
# Out:
# 0.94

# %% [markdown]
# # Task 2.2. dataset2.csv

# %%
df4 = pd.read_csv('/content/drive/MyDrive/20130127_MaiThanhThuan/dataset2.csv')
X1_train = df4[['x1']]
X2_train = df4[['x2']]
X3_train = df4[['x3']]
y_train = df4[['y']]
X1_train
# Out:
#           x1
# 0    2.41710
# 1    1.98150
# 2    1.82850
# 3    1.50480
# 4    0.27489
# ..       ...
# 594  1.64550
# 595 -1.16320
# 596 -1.61920
# 597 -0.34407
# 598 -0.12172
#
# [599 rows x 1 columns]

# %%
#code
regressor = LinearRegression()
regressor.fit(X1_train, y_train)
print(regressor.intercept_)
print(regressor.coef_)
# Out:
# [3.82046433]
# [[2.97886771]]

# %%
regressor = LinearRegression()
regressor.fit(X2_train, y_train)
print(regressor.intercept_)
print(regressor.coef_)
# Out:
# [4.32501785]
# [[3.97078067]]

# %%
regressor = LinearRegression()
regressor.fit(X3_train, y_train)
print(regressor.intercept_)
print(regressor.coef_)
# Out:
# [3.63075755]
# [[4.92237006]]

# %%
y_pred = regressor.predict(X1_train)
y_pred
# Out:
# array([[11.02068548],
#        [ 9.7230907 ],
#        [ 9.26732394],
#        [ 8.30306447],
#        [ 4.63932528],
#        [ 2.61211643],
#        [-1.73333663],
#        [ 6.12342696],
#        [ 9.24140779],
#        [ 0.46328042],
#        [ 8.88692254],
#        [-2.57278155],
#        [ 2.01515135],
#        [-4.11606771e+00],
#        [-4.46351102e+00],
#        [ 3.73217506e-01],
#        [ 4.75628434e+00],
#        [ 5.55357739e+00],
#        [-8.06024939e-01],
#        [ 1.25191208e+01],
#        [ 1.07922283e+01],
#        [ 3.22403949e+00],
#        [ 1.38957905e+01],
#        [ 5.87894316e+00],
#        [-9.47781809e-01],
#        [ 1.04916402e+01],
#        [ 3.35761655e+00],
#        [-6.39252150e-01],
#        [ 1.33672796e+01],
#        [-2.76957598e+00],
#        [ 4.57445038e+00],
#        [ 1.36944719e+01],
#        [ 7.26974880e+00],
#        [ 6.60170466e+00],
#        [ 3.72245188e+00],
#        [ 5.86925445e+00],
#        [ 1.24913254e+01],
#        [ 1.86750169e+00],
#        [-1.06015490e+00],
#        [ 2.80667073e+00],
#        [-1.69905875e-01],
#        [ 3.22443657e+00],
#        [ 6.85670819e+00],
#        [ 5.01279677e+00],
#        [ 2.05059439e+00],
#        [ 1.17396566e+01],
#        [ 3.61146333e-01]])

# %%
from sklearn import metrics
r2 = metrics.r2_score(X1_train, y_pred)
r2
# Out:
# -10.125312431273185

# %%
from sklearn import metrics
r2 = metrics.r2_score(X2_train, y1_pred)
r2
# Out:
# -15.884677954889934

# %% [markdown]
# # Task 2.3. Apply LinearRegression to the following dataset:
# *   Red wine quality: https://archive.ics.uci.edu/ml/machine-learning-databases/wine-quality/winequality-red.csv . The dataset includes info about the chemical properties of different types of wine and how they relate to overall quality.

# %%
# Reading the dataset
wine_data = pd.read_csv("https://archive.ics.uci.edu/ml/machine-learning-databases/wine-quality/winequality-red.csv", sep=";")

# %%
X = wine_data.iloc[:, :-1]
y = wine_data.iloc[:, -1]

# %%
# Fit model
lm = LinearRegression()
lm.fit(X, y)
# Out:
# LinearRegression()

# %%
#print
print("Intercept:", lm.intercept_)
print("Coefficients:", lm.coef_)
# Out:
# Intercept: 21.96520844944842
# Coefficients: [ 2.49905527e-02 -1.08359026e+00 -1.82563948e-01  1.63312698e-02
#  -1.87422516e+00  4.36133331e-03 -3.26457970e-03 -1.78811638e+01
#  -4.13653144e-01  9.16334413e-01  2.76197699e-01]

# %% [markdown]
# # Task 2.4. Apply LinearRegression to the following dataset:
# *   Energy efficiency: https://archive.ics.uci.edu/ml/datasets/Energy+efficiency.

# %%
# Reading the dataset
energy_data = pd.read_excel("https://archive.ics.uci.edu/ml/machine-learning-databases/00242/ENB2012_data.xlsx")
energy_data
# Out:
#        X1     X2     X3      X4   X5  X6   X7  X8     Y1     Y2
# 0    0.98  514.5  294.0  110.25  7.0   2  0.0   0  15.55  21.33
# 1    0.98  514.5  294.0  110.25  7.0   3  0.0   0  15.55  21.33
# 2    0.98  514.5  294.0  110.25  7.0   4  0.0   0  15.55  21.33
# 3    0.98  514.5  294.0  110.25  7.0   5  0.0   0  15.55  21.33
# 4    0.90  563.5  318.5  122.50  7.0   2  0.0   0  20.84  28.28
# ..    ...    ...    ...     ...  ...  ..  ...  ..    ...    ...
# 763  0.64  784.0  343.0  220.50  3.5   5  0.4   5  17.88  21.40
# 764  0.62  808.5  367.5  220.50  3.5   2  0.4   5  16.54  16.88
# 765  0.62  808.5  367.5  220.50  3.5   3  0.4   5  16.44  17.11
# 766  0.62  808.5  367.5  220.50  3.5   4  0.4   5  16.48  16.61
# 767  0.62  808.5  367.5  220.50  3.5   5  0.4   5  16.64  16.03
#
# [768 rows x 10 columns]

# %%
#code
X = energy_data.iloc[:, :-2] 
y = energy_data.iloc[:, -2:]

# %%
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# %%
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.3, random_state=42)

# %%
lm = LinearRegression()
lm.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred = lm.predict(X_test)

# %%
r2 = r2_score(y_test, y_pred)
print("R-squared score:", r2)
# Out:
# R-squared score: 0.8994151705350466

# %% [markdown]
# # Finally,
# Save a copy in your Github. Remember renaming the notebook.
